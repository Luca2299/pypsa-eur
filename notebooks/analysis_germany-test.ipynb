# %% [markdown]
# # Different network builds in PyPSA

# %%
import pypsa
import matplotlib.pyplot as plt

# %% [markdown]
# ### Smallest network: 20 clusters
# 7 days in 2025

# %%
#/home/lucakristin/Desktop/my_pypsa/pypsa-eur/resources/germany-test/networks/base_s_20_elec_.nc
n = pypsa.Network("resources/germany-test/networks/base_s_20_elec_.nc")
# Out:
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, lines, links, loads, stores, sub_networks

# %%
n.plot()
# Out:
# {'nodes': {'Bus': <matplotlib.collections.PatchCollection at 0x7b415b096510>},
#  'branches': {'Link': <matplotlib.collections.LineCollection at 0x7b415b096660>,
#   'Line': <matplotlib.collections.LineCollection at 0x7b415b099bd0>},
#  'flows': {}}

# %% [markdown]
# ### 100N - Network
# 7 days in 2025

# %%
n_100 = pypsa.Network("resources/germany-test/networks/base_s_100_elec_.nc")
n_100.plot()
# Out:
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, lines, links, loads, stores, sub_networks
# INFO:pypsa.network.io:Imported network 'PyPSA-Eur (osm vlatest)' has buses, carriers, lines, links, shapes, transformers

# %% [markdown]
# ### Plotting the base network: base.nc

# %%
n_100_b = pypsa.Network("pypsa-eur/resources/germany-test/networks/base_s.nc")
n_100_b.plot()
# Out:
# INFO:pypsa.network.io:Imported network 'PyPSA-Eur (osm vlatest)' has buses, carriers, lines, links, shapes
# {'nodes': {'Bus': <matplotlib.collections.PatchCollection at 0x796a012497f0>},
#  'branches': {'Link': <matplotlib.collections.LineCollection at 0x796a0124a510>,
#   'Line': <matplotlib.collections.LineCollection at 0x796a00e8efd0>},
#  'flows': {}}

# %%
for component in n.components:
    print(component)
# Out:
# 'Bus' Components
# 'Carrier' Components
# 'Generator' Components
# 'Load' Components
# 'Link' Components
# 'Store' Components
# 'Line' Components
# 'LineType' Components
# 'TransformerType' Components
# 'SubNetwork' Components

# %%
n.snapshots[:10]
# Out:
# DatetimeIndex(['2025-03-01', '2025-03-02', '2025-03-03', '2025-03-04',
#                '2025-03-05', '2025-03-06', '2025-03-07'],
#               dtype='datetime64[ns]', name='snapshot', freq=None)

# %%
len(n.snapshots)
# Out:
# 7

# %%
n.lines.head()
# Out:
#         bus0    bus1                         type          x         r    g  \
# name
# 0      DE0 0  DE0 12  Al/St 240/40 4-bundle 380.0  10.371010  1.532275  0.0
# 1      DE0 0  DE0 16  Al/St 240/40 4-bundle 380.0   7.990266  0.974421  0.0
# 10     DE0 1   DE0 8  Al/St 240/40 4-bundle 380.0  18.564393  2.263951  0.0
# 11    DE0 10  DE0 17  Al/St 240/40 4-bundle 380.0   6.855744  0.884296  0.0
# 12    DE0 10   DE0 2  Al/St 240/40 4-bundle 380.0   0.650166  0.099413  0.0
#
#              b         s_nom  s_nom_mod  s_nom_extendable  ...  x_pu  r_pu  \
# name                                                       ...
# 0     0.002532   4379.317262        0.0              True  ...   0.0   0.0
# 1     0.001267   5094.307835        0.0              True  ...   0.0   0.0
# 10    0.002945   5094.307835        0.0              True  ...   0.0   0.0
# 11    0.004151   8982.069078        0.0              True  ...   0.0   0.0
# ...

# %%
n.generators.head()
# Out:
#                     bus control type       p_nom  p_nom_mod  p_nom_extendable  \
# name
# DE0 0 CCGT        DE0 0      PQ        820.57117        0.0              True
# DE0 0 OCGT        DE0 0      PQ        538.93966        0.0              True
# DE0 0 biomass     DE0 0      PQ         94.89200        0.0             False
# DE0 0 coal        DE0 0      PQ       5920.00000        0.0             False
# DE0 0 geothermal  DE0 0      PQ          7.80000        0.0             False
#
#                    p_nom_min  p_nom_max  p_nom_set  p_min_pu  ...  \
# name                                                          ...
# DE0 0 CCGT         820.57117        inf        NaN       0.0  ...
# DE0 0 OCGT         538.93966        inf        NaN       0.0  ...
# DE0 0 biomass       94.89200        inf        NaN       0.0  ...
# DE0 0 coal        5920.00000        inf        NaN       0.0  ...
# DE0 0 geothermal     7.80000        inf        NaN       0.0  ...
#
# ...

# %%
n.carriers.head()
# Out:
# <Axes: xlabel='snapshot'>

# %% [markdown]
# ### Network wity NUT2 administrative clustering: 38 Nodes

# %%
n_adm = pypsa.Network("resources/germany-adm/networks/base_s_adm_elec_.nc")
# Out:
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, lines, links, loads, stores, sub_networks

# %%
n_adm.plot()
# Out:
# {'nodes': {'Bus': <matplotlib.collections.PatchCollection at 0x7b4151a665d0>},
#  'branches': {'Link': <matplotlib.collections.LineCollection at 0x7b4151a66710>,
#   'Line': <matplotlib.collections.LineCollection at 0x7b4151a66850>},
#  'flows': {}}

# %%
len(n_adm.snapshots)
# Out:
# 7

# %%
n_adm.loads_t.p_set.sum(axis=1).plot(figsize=(10, 5))
# Out:
# <Axes: xlabel='snapshot'>

# %%
n_470 = pypsa.Network("resources/germany-test/networks/base_s_470_elec_.nc")
n_470.plot()
# Out:
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, lines, links, loads, stores, sub_networks
# {'nodes': {'Bus': <matplotlib.collections.PatchCollection at 0x7b4150a7cf50>},
#  'branches': {'Link': <matplotlib.collections.LineCollection at 0x7b4150a7d090>,
#   'Line': <matplotlib.collections.LineCollection at 0x7b4150a7d1d0>},
#  'flows': {}}

# %%
n_365 = pypsa.Network("resources/germany-365/networks/base_s_all.nc")
# Out:
# INFO:pypsa.network.io:Imported network 'PyPSA-Eur (osm vlatest)' has buses, carriers, lines, links, shapes

# %%
n_365.plot()
# Out:
# {'nodes': {'Bus': <matplotlib.collections.PatchCollection at 0x7a3fd38b5940>},
#  'branches': {'Link': <matplotlib.collections.LineCollection at 0x7a3fd38b6660>,
#   'Line': <matplotlib.collections.LineCollection at 0x7a3fd36fefd0>},
#  'flows': {}}

# %% [markdown]
# ## 24h resolution

# %%
n_24h = pypsa.Network("pypsa-eur/resources/germany_24h/networks/base_s_all.nc")
n_24h.plot()
# Out:
# INFO:pypsa.network.io:Imported network 'PyPSA-Eur (osm vlatest)' has buses, carriers, lines, links, shapes
# {'nodes': {'Bus': <matplotlib.collections.PatchCollection at 0x796a00c45450>},
#  'branches': {'Link': <matplotlib.collections.LineCollection at 0x796a00c45590>,
#   'Line': <matplotlib.collections.LineCollection at 0x796a00c456d0>},
#  'flows': {}}

# %%
n_24h.loads_t.p_set.sum(axis=1).plot(figsize=(10, 5))
# Out:
# <Axes: xlabel='snapshot'>
